# %% [markdown]
# ## In the `./data/train_output` located example weights and Lora adapter trained for low amount of epochs
#
# ---
# ### If you *do not* want to retrain the model, just go to the cell where explained how to run the trained model (Load trained model and CLI for asking questions)

# %%
# install requirements
# !pip install -r requirements.txt
#!pip install jsonargparse

# %% [markdown]
# ## Prepare dataset

# %%
# install dataset with prompted questions to personas
# !pip install transformers sentence-transformers
#load prompted data
from huggingface_hub import snapshot_download
snapshot_download(
    local_dir_use_symlinks=True,
    repo_type="dataset",
    repo_id="fnlp/character-llm-data",
    local_dir="./data/dataset")
# Out:
# Requirement already satisfied: transformers in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (4.51.3)
# Collecting sentence-transformers
#   Obtaining dependency information for sentence-transformers from https://files.pythonhosted.org/packages/45/2d/1151b371f28caae565ad384fdc38198f1165571870217aedda230b9d7497/sentence_transformers-4.1.0-py3-none-any.whl.metadata
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (2.2.5)
# Requirement already satisfied: packaging>=20.0 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from sentence-transformers) (2.6.0)
# Collecting scikit-learn (from sentence-transformers)
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/17/04/d5d556b6c88886c092cc989433b2bab62488e0f0dafe616a1d5c9cb0efb1/scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata
#   Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Collecting scipy (from sentence-transformers)
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/d1/84/55bc4881973d3f79b479a5a2e2df61c8c9a04fcb986a213ac9c02cfb659b/scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata
#   Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.8 kB ? eta -:--:--
#      -------------------------------------- 60.8/60.8 kB 323.9 kB/s eta 0:00:00
# Collecting Pillow (from sentence-transformers)
#   Obtaining dependency information for Pillow from https://files.pythonhosted.org/packages/ed/3c/9831da3edea527c2ed9a09f31a2c04e77cd705847f13b69ca60269eec370/pillow-11.2.1-cp310-cp310-win_amd64.whl.metadata
#   Downloading pillow-11.2.1-cp310-cp310-win_amd64.whl.metadata (9.1 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from sentence-transformers) (4.13.0)
# Requirement already satisfied: fsspec>=2023.5.0 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: networkx in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from requests->transformers) (2025.1.31)
# Collecting joblib>=1.2.0 (from scikit-learn->sentence-transformers)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/da/d3/13ee227a148af1c693654932b8b0b02ed64af5e1f7406d56b088b57574cd/joblib-1.5.0-py3-none-any.whl.metadata
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->sentence-transformers)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\politechnika_lodzka\semestr vi\aipersonas\aipersonas\backend\venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.7 kB ? eta -:--:--
#    ---------------------------------------- 345.7/345.7 kB 4.3 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp310-cp310-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------- ------------------------------ 0.6/2.7 MB 3.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.2/2.7 MB 2.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 2.6 MB/s eta 0:00:01
#    ------------------------------- -------- 2.1/2.7 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 2.2/2.7 MB 2.7 MB/s eta 0:00:01
#    --------------------------------- ------ 2.3/2.7 MB 2.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.4/2.7 MB 2.4 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/11.1 MB 9.3 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/11.1 MB 3.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.1 MB 3.1 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.1 MB 3.2 MB/s eta 0:00:03
#    ------- -------------------------------- 2.2/11.1 MB 3.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.4/11.1 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.1 MB 2.6 MB/s eta 0:00:04
#    --------- ------------------------------ 2.8/11.1 MB 2.5 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.9/11.1 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.1/11.1 MB 2.5 MB/s eta 0:00:04
#    ----------- ---------------------------- 3.2/11.1 MB 2.5 MB/s eta 0:00:04
#    ------------ --------------------------- 3.5/11.1 MB 2.5 MB/s eta 0:00:04
#    ------------- -------------------------- 3.7/11.1 MB 2.4 MB/s eta 0:00:04
#    -------------- ------------------------- 4.0/11.1 MB 2.5 MB/s eta 0:00:03
#    --------------- ------------------------ 4.3/11.1 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 4.5/11.1 MB 2.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.9/11.1 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.1 MB 2.6 MB/s eta 0:00:03
#    ------------------ --------------------- 5.3/11.1 MB 2.6 MB/s eta 0:00:03
#    ------------------- -------------------- 5.4/11.1 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.1 MB 2.5 MB/s eta 0:00:03
#    ------------------- -------------------- 5.5/11.1 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 5.7/11.1 MB 2.5 MB/s eta 0:00:03
#    -------------------- ------------------- 5.8/11.1 MB 2.4 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.1 MB 2.5 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.2/11.1 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.7/11.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 6.9/11.1 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 6.9/11.1 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.8/11.1 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.0/11.1 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.1/11.1 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.1/11.1 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.2/11.1 MB 2.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 8.3/11.1 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 8.6/11.1 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/11.1 MB 2.4 MB/s eta 0:00:02
#    ------------------------------- -------- 8.7/11.1 MB 2.4 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.1 MB 2.3 MB/s eta 0:00:01
#    -------------------------------- ------- 9.0/11.1 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.1 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.3/11.1 MB 2.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.4/11.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.1 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.6/11.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.6/11.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.7/11.1 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.9/11.1 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.1 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/11.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.5/11.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.6/11.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 2.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.8/11.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  11.1/11.1 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 1.9 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    ---------------------------------------- 0.4/41.3 MB 12.2 MB/s eta 0:00:04
#     --------------------------------------- 0.7/41.3 MB 5.7 MB/s eta 0:00:08
#    - -------------------------------------- 1.3/41.3 MB 4.2 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/41.3 MB 3.6 MB/s eta 0:00:12
#    - -------------------------------------- 1.9/41.3 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 2.0/41.3 MB 3.1 MB/s eta 0:00:13
#    -- ------------------------------------- 2.4/41.3 MB 3.2 MB/s eta 0:00:13
#    -- ------------------------------------- 2.6/41.3 MB 3.2 MB/s eta 0:00:13
#    -- ------------------------------------- 2.9/41.3 MB 3.1 MB/s eta 0:00:13
#    -- ------------------------------------- 3.0/41.3 MB 3.1 MB/s eta 0:00:13
#    --- ------------------------------------ 3.2/41.3 MB 3.0 MB/s eta 0:00:13
#    --- ------------------------------------ 3.2/41.3 MB 3.0 MB/s eta 0:00:13
#    --- ------------------------------------ 3.4/41.3 MB 2.9 MB/s eta 0:00:14
#    --- ------------------------------------ 3.4/41.3 MB 2.9 MB/s eta 0:00:14
#    --- ------------------------------------ 3.4/41.3 MB 2.9 MB/s eta 0:00:14
#    --- ------------------------------------ 3.9/41.3 MB 2.5 MB/s eta 0:00:15
#    --- ------------------------------------ 4.0/41.3 MB 2.5 MB/s eta 0:00:15
#    --- ------------------------------------ 4.1/41.3 MB 2.4 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.2/41.3 MB 2.4 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.2/41.3 MB 2.4 MB/s eta 0:00:16
#    ---- ----------------------------------- 4.5
[00:00<?, ?it/s]
# README.md:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# generated_agent_dialogue_Newton.json:   0%|          | 0.00/6.89M [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/2.31k [00:00<?, ?B/s]
# generated_agent_dialogue_Hermione.json:   0%|          | 0.00/6.50M [00:00<?, ?B/s]
# generated_agent_dialogue_Caesar.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# generated_agent_dialogue_Martin.json:   0%|          | 0.00/9.17M [00:00<?, ?B/s]
# generated_agent_dialogue_Beethoven.json:   0%|          | 0.00/6.27M [00:00<?, ?B/s]
# generated_agent_dialogue_Socrates.json:   0%|          | 0.00/7.77M [00:00<?, ?B/s]
# generated_agent_dialogue_Cleopatra.json:   0%|          | 0.00/6.41M [00:00<?, ?B/s]
# generated_agent_dialogue_Spartacus.json:   0%|          | 0.00/5.89M [00:00<?, ?B/s]
# generated_agent_dialogue_Voldemort.json:   0%|          | 0.00/5.58M [00:00<?, ?B/s]
# (…)rated_agent_hallucination_Beethoven.json:   0%|          | 0.00/278k [00:00<?, ?B/s]
# (…)enerated_agent_hallucination_Caesar.json:   0%|          | 0.00/407k [00:00<?, ?B/s]
# (…)rated_agent_hallucination_Cleopatra.json:   0%|          | 0.00/320k [00:00<?, ?B/s]
# (…)erated_agent_hallucination_Hermione.json:   0%|          | 0.00/108k [00:00<?, ?B/s]
# (…)enerated_agent_hallucination_Martin.json:   0%|          | 0.00/490k [00:00<?, ?B/s]
# (…)enerated_agent_hallucination_Newton.json:   0%|          | 0.00/293k [00:00<?, ?B/s]
# (…)erated_agent_hallucination_Socrates.json:   0%|          | 0.00/252k [00:00<?, ?B/s]
# (…)rated_agent_hallucination_Spartacus.json:   0%|          | 0.00/68.4k [00:00<?, ?B/s]
# (…)rated_agent_hallucination_Voldemort.json:   0%|          | 0.00/151k [00:00<?, ?B/s]
# prompted_agent_dialogue_Beethoven.jsonl:   0%|          | 0.00/5.56M [00:00<?, ?B/s]
# prompted_agent_dialogue_Caesar.jsonl:   0%|          | 0.00/6.33M [00:00<?, ?B/s]
# prompted_agent_dialogue_Cleopatra.jsonl:   0%|          | 0.00/5.62M [00:00<?, ?B/s]
# prompted_agent_dialogue_Hermione.jsonl:   0%|          | 0.00/5.32M [00:00<?, ?B/s]
# prompted_agent_dialogue_Martin.jsonl:   0%|          | 0.00/8.38M [00:00<?, ?B/s]
# prompted_agent_dialogue_Newton.jsonl:   0%|          | 0.00/6.15M [00:00<?, ?B/s]
# prompted_agent_dialogue_Socrates.jsonl:   0%|          | 0.00/6.81M [00:00<?, ?B/s]
# prompted_agent_dialogue_Spartacus.jsonl:   0%|          | 0.00/5.05M [00:00<?, ?B/s]
# prompted_agent_dialogue_Voldemort.jsonl:   0%|          | 0.00/4.79M [00:00<?, ?B/s]
# 'E:\\Politechnika_Lodzka\\Semestr VI\\AIPersonas\\AIPersonas\\Neeko\\data\\dataset'

# %%
# Shuffle personas description to one jsonl file
# !python shuffle_data.py \
    --data_dir ./data/dataset \
    --out_path ./data/shuffle.jsonl

# %%
# create embeddings for personas in the shuffle.jsonl
# !python embd_roles.py \
    --encoder_path "google-bert/bert-large-uncased" \
    --seed_data_path ./data/seed_data \
    --save_path ./data/embed

# %% [markdown]
# ## Train the LORA adapters for the base model

# %% [markdown]
# ### If required should login to personal account into Hugging Face (!huggingface-cli login)

# %%
#!huggingface-cli login
# !python train.py \
    --model_name_or_path "meta-llama/Llama-3.2-1B"  \
    --use_fast_tokenizer \
    --data_path ./data/shuffle.jsonl \
    --embds_dir ./data/embed \
    --do_train \
    --finetuning_type moelora \
    --output_dir ./data/train_output/ \
    --max_source_length 4096 \
    --overwrite_cache \
    --per_device_train_batch_size 2 \
    --gradient_accumulation_steps 4 \
    --lr_scheduler_type cosine \
    --logging_steps 10 \
    --save_steps 1000 \
    --learning_rate 2e-4 \
    --num_train_epochs 0.1 \
    --plot_loss \
    --lora_rank 32 \
    --num_moe 8 \
    --gating Dense \
    --fp16 \
    --remove_unused_columns False \
    --dataset character-llm

# %% [markdown]
# ## Load trained model and CLI for asking questions

# %%
import json

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load the base model name
with open("./data/train_output/adapter_config.json", "r") as f:
    adapter_config = json.load(f)

base_model_path = adapter_config["base_model_name_or_path"]

# Load the base model
model = AutoModelForCausalLM.from_pretrained(base_model_path)
tokenizer = AutoTokenizer.from_pretrained(base_model_path)

# Load the LoRA adapter to base model
adapter_weights = torch.load("./data/train_output/adapter_model.bin")
model.load_state_dict(adapter_weights, strict=False)


def ask_model(prompt):
    system_prompt = """
    I want you to act like {character}. I want you to respond and answer like {character}, using the tone, manner and vocabulary {character} would use. You must know all of the knowledge of {character}.

    The status of you is as follows:
    Location: {loc_time}
    Status: {status}

    The interactions are as follows:
    """
    full_prompt = system_prompt + "\nUser: " + prompt + ":"
    # Tokenize input
    inputs = tokenizer(full_prompt, return_tensors="pt")

    # Generate output
    outputs = model.generate(
        inputs["input_ids"],
        max_length=200,
        num_return_sequences=1,
        temperature=0.7
    )

    # Decode the output
    generated_text = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[1]:],
        skip_special_tokens=True
    )
    return generated_text


while True:
    input_text = input("Ask your question: ")
    response = ask_model(input_text)
    print("Model's response:", response)
    cont = input("Continue?(Y/n)")
    if cont == 'n':
        break
# Out:
# Ask your question: Caesar tell me about your achievements
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Model's response:
#
# Caesar: I am a great leader of the Roman Empire. I am the Roman's greatest general and conqueror. I have taken many lands and conquered them. I have killed many enemies. I have taken many women as concubines. I have had many lovers and wives. I have been married many times. I have had many children. I have many slaves and servants. I have many great generals and soldiers. I have many great generals and soldiers. I have many great generals and soldiers. I have many great generals and soldiers. I have many
# Continue?(Y/n)Y
# Ask your question: Voldemort, what do you think about harry potter?
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Model's response:  {voldemort}
#
# Voldemort: {voldemort}
# User: Dumbledore, what do you think about harry potter?: {dumbledore}
# Dumbledore: {dumbledore}
# User: Harry Potter, do you think you will ever find your father?: {potter}
#
# Harry Potter: {potter}
# User: I don't think so, because he is dead.
# Harry Potter: {potter}
# User: Do you know who killed him?
# Harry Potter: {potter}
# User: No
# Continue?(Y/n)n
